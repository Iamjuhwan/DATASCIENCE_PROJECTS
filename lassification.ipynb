# %% [markdown]
# <a href="https://colab.research.google.com/github/Iamjuhwan/DATASCIENCE_PROJECTS/blob/main/lassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dl=pd.read_csv('/winequalityN.csv')
df = pd.read_csv('/breastcancer.csv')

# %%
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.head(8).T
# Out:
#                                 0         1         2         3         4  \
# id                         842302    842517  84300903  84348301  84358402
# diagnosis                       M         M         M         M         M
# radius_mean                 17.99     20.57     19.69     11.42     20.29
# texture_mean                10.38     17.77     21.25     20.38     14.34
# perimeter_mean              122.8     132.9     130.0     77.58     135.1
# area_mean                  1001.0    1326.0    1203.0     386.1    1297.0
# smoothness_mean            0.1184   0.08474    0.1096    0.1425    0.1003
# compactness_mean           0.2776   0.07864    0.1599    0.2839    0.1328
# concavity_mean             0.3001    0.0869    0.1974    0.2414     0.198
# concave points_mean        0.1471   0.07017    0.1279    0.1052    0.1043
# symmetry_mean              0.2419    0.1812    0.2069    0.2597    0.1809
# fractal_dimension_mean    0.07871   0.05667   0.05999   0.09744   0.05883
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
df.area_se
# Out:
# 0      153.40
# 1       74.08
# 2       94.03
# 3       27.23
# 4       94.44
#         ...
# 564    158.70
# 565     99.04
# 566     48.55
# 567     86.22
# 568     19.15
# Name: area_se, Length: 569, dtype: float64

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.diagnosis
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
df.diagnosis.value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
(df.diagnosis == 'M')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 564     True
# 565     True
# 566     True
# 567     True
# 568    False
# Name: diagnosis, Length: 569, dtype: bool

# %%
df.diagnosis = (df.diagnosis == 'M').astype(int)

# %%
df.diagnosis
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
df.diagnosis.value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, test_size=0.2, random_state=42)

# %%
len(train), len(test)
# Out:
# (455, 114)

# %%
df_train, df_val = train_test_split(train, test_size=0.25, random_state=42)

# %%
len(df_train), len(df_val), len(test)
# Out:
# (341, 114, 114)

# %%
df_train
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 217   8811779          0       10.200         17.48           65.05
# 283   8912280          1       16.240         18.77          108.80
# 0      842302          1       17.990         10.38          122.80
# 504    915186          0        9.268         12.87           61.49
# 251  88518501          0       11.500         18.45           73.28
# ..        ...        ...          ...           ...             ...
# 57     857793          1       14.710         21.59           95.55
# 492    914062          1       18.010         20.56          118.40
# 418    906024          0       12.700         12.17           80.88
# 385     90291          1       14.600         23.29           93.97
# 325  89511502          0       12.670         17.30           81.25
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 217      321.2          0.08054           0.05907         0.05774
# ...

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = test.reset_index(drop=True)

# %%
y_train = df_train.reset_index(drop=True)
y_val = df_val.reset_index(drop=True)
y_test = df_test.reset_index(drop=True)

# %%
y_train = (df_train.diagnosis == 'M').astype(int)
y_val = (df_val.diagnosis == 'M').astype(int)
y_test = (df_test.diagnosis == 'M').astype(int)

# %%
del df_train['diagnosis']
del df_val['diagnosis']
del df_test['diagnosis']

# %% [markdown]
# ## EDA

# %%
train = train.reset_index(drop=True)

# %%
train
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      859471          0        9.029         17.33           58.79
# 1      873593          1       21.090         26.57          142.70
# 2      859196          0        9.173         13.86           59.20
# 3    88466802          0       10.650         25.22           68.01
# 4      858970          0       10.170         14.88           64.55
# ..        ...        ...          ...           ...             ...
# 450    859711          0        8.888         14.64           58.79
# 451    863031          0       11.640         18.33           75.17
# 452   8910721          0       14.290         16.82           90.30
# 453    908489          1       13.980         19.62           91.12
# 454    862965          0       12.180         20.52           77.22
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0        250.5          0.10660           0.14130         0.31300
# ...

# %%
train.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
train.diagnosis
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 450    0
# 451    0
# 452    0
# 453    1
# 454    0
# Name: diagnosis, Length: 455, dtype: int64

# %%
train.diagnosis.value_counts()
# Out:
# diagnosis
# 0    286
# 1    169
# Name: count, dtype: int64

# %%
train.diagnosis.value_counts(normalize=True)
# Out:
# diagnosis
# 0    0.628571
# 1    0.371429
# Name: proportion, dtype: float64

# %%
train.dtypes
# Out:
# id                           int64
# diagnosis                    int64
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...
